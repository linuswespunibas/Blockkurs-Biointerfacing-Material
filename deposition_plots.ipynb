# %%
# Funktion, um Plots zu machen
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit
import math

# %%
# Enable LaTeX rendering
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Computer Modern Roman'
plt.rcParams['text.latex.preamble'] = r"\usepackage{amsmath}"

# %%
# funktionen
def simple_plot(x,y):
    # Create some data

    # Plot
    plt.plot(x, y, label=r'$\sin(x)$')
    plt.xlabel(r'$x$')
    plt.ylabel(r'$\sin(x)$')
    plt.title(r'Plot of $\sin(x)$ using LaTeX')
    plt.legend()
    plt.show()




def plot_with_one_axis_with_ONE_points(data_x, data_y, name_x, name_y, p1_x, p1_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="5", main_color="#1f77b4"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    # col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5"

    # Plot data
    plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle='', markersize=marker_size, color=main_color) 
    # plt.plot(0.096,58.496, label=f"$x = 0.096$ mm", marker='o', markersize=6)
    # plt.plot(0.166,16.31, label=f"$x = 0.166$ mm", marker='o', markersize=6)
    plt.plot(p1_x,p1_y, label=f"$x = {p1_x}, y = {p1_y}$ mm", marker='o', markersize=6, color = "orange")
    

    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_with_points(data_x, data_y, name_x, name_y, p1_x, p1_y, p2_x, p2_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="5", main_color="#1f77b4"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    # col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5"

    # Plot data
    plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle='', markersize=marker_size, color=main_color) 
    # plt.plot(0.096,58.496, label=f"$x = 0.096$ mm", marker='o', markersize=6)
    # plt.plot(0.166,16.31, label=f"$x = 0.166$ mm", marker='o', markersize=6)
    plt.plot(p1_x,p1_y, label=f"$x = 0.096$ mm", marker='o', markersize=6, color = "orange")
    plt.plot(p2_x,p2_y, label=f"$x = 0.166$ mm", marker='o', markersize=6, color = "green")
    

    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_twoY(data_x_1, data_y_1, data_x_2, data_y_2,  name_x, name_y, plot_title="title", filename_to_save="nopdf", line_style="", label1="nolabel", label2="nolabel", col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5", plot_point="nopoint"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    


    
    # Plot data
    plt.plot(data_x_1, data_y_1, label=label1, marker=marker_type, linestyle=line_style, markersize=marker_size, color=col1) # color='red') 
    plt.plot(data_x_2, data_y_2, label=label2, marker=marker_type, color=col2, linestyle=line_style, markersize=marker_size) #, marker='o', linestyle='') # color='red') 
    
    if plot_point != "nopoint":
        # xx, yy = plot_point
        xx, yy, labell, markerr, markersizee, colorr = plot_point

        plt.plot(xx, yy, label=labell, marker=markerr, markersize=markersizee, color=colorr)

        #plt.plot(xx, yy, label="HALLO", markersize=10)

    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_and_two_fits(data_x, data_y, x_fit_1, y_fit_1, x_fit_2, y_fit_2, name_x, name_y, main_color="#1f77b4", colorfit1="orange", colorfit2="green", plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="5"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    
    # Plot data
    plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle='', markersize = marker_size, color=main_color) 
    plt.plot(x_fit_1, y_fit_1, color=colorfit1)
    plt.plot(x_fit_2, y_fit_2, color=colorfit2)
    
    
    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

# plot with two axes
def plot_with_two_axes(data_x,data_y_one, data_y_two, name_x, name_y1, name_y2, plot_title="title", filename_to_save="LOL.pdf", xmin=0, xmax=500000, ymin1=0, ymax1=1000, ymin2=-2, ymax2=1):
    fig, ax1 = plt.subplots() 
    
    ax1.set_xlabel(name_x) 
    ax1.set_ylabel(name_y1, color = 'red') 
    plot_1 = ax1.plot(data_x, data_y_one, color = 'red', label='impedance') 
    ax1.tick_params(axis ='y') #, labelcolor = 'red') 
    # ax1.ylim(0,.9)
    # ax1.xlim(0,.9)
    ax1.set_xlim([xmin, xmax])
    ax1.set_ylim([ymin1, ymax1])

    ax2 = ax1.twinx() 
    ax2.set_ylabel(name_y2, color = 'blue') 
    plot_2 = ax2.plot(data_x, data_y_two, color = 'blue', label = 'phase') 
    ax2.tick_params(axis ='y') #, labelcolor = 'blue') 

    ax1.set_xlim([xmin, xmax])
    ax2.set_ylim([ymin2, ymax2])
    
    fig.tight_layout()

    lns = plot_1 + plot_2
    labels = [l.get_label() for l in lns]
    
    plt.title(plot_title)
    plt.legend(lns, labels, loc=0)
    
    fnts =  filename_to_save + ".pdf"
    plt.savefig(fnts)
    plt.show()


def plot_with_one_axis_twoY_and_error_bars(data_x_1, data_y_1, data_y_1_error, data_x_2, data_y_2,  name_x, name_y, plot_title="title", filename_to_save="noname.pdf", line_style="", label1="nolabel", label2="nolabel", col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5", capsize_errorbars=5): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    
    # Plot data
    plt.errorbar(data_x_1, data_y_1, yerr=data_y_1_error, fmt=marker_type, label=label1, capsize=capsize_errorbars, color=col1)
    # plt.plot(data_x_1, data_y_1, label=label1, marker=marker_type, linestyle=line_style, markersize=marker_size, color=col1) # color='red') 
    plt.plot(data_x_2, data_y_2, label=label2, color=col2, linestyle="-") #, marker='o', linestyle='') # color='red') 



    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_twoY_with_point_from_list(lll): # data_x_1, data_y_1, data_x_2, data_y_2,  name_x, name_y, plot_title="title", filename_to_save="nopdf", line_style="", label1="nolabel", label2="nolabel", col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5", plot_point="nopoint"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    
    l = lll
    
    plt.figure()  # No need for subplots when using a single axis
    
    for l in lll:
        #data_x_1, data_y_1, data_x_2, data_y_2, name_x, name_y, plot_title, filename_to_save, 
        data_x_1, data_y_1, data_x_2, data_y_2, name_x, name_y, plot_title, filename_to_save, line_style, label1, label2, col1, col2, marker_type, marker_size, plot_point = l

        # Plot data
        plt.plot(data_x_1, data_y_1, label=label1, marker=marker_type, linestyle=line_style, markersize=marker_size, color=col1) # color='red') 
        plt.plot(data_x_2, data_y_2, label=label2, marker=marker_type, color=col2, linestyle=line_style, markersize=marker_size) #, marker='o', linestyle='') # color='red') 
        
        if plot_point != "nopoint":
            # xx, yy = plot_point
            xx, yy, labell, markerr, markersizee, colorr = plot_point

            plt.plot(xx, yy, label=labell, marker=markerr, markersize=markersizee, color=colorr)

            #plt.plot(xx, yy, label="HALLO", markersize=10)

    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()


def plot_with_one_axis(list_of_data:list, name_x="x", name_y="y", plot_title="title", filename_to_save="nopdf", marker_type="o", marker_size="5"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    
    # Plot data

    # [data_x, data_y, label, color]
    
    for l in list_of_data:
        data_x, data_y, label, colorr, line_style = l
        plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle=line_style, color=colorr, markersize=marker_size) # color='red') 
    
    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".svg"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_with_points(list_of_data:list, list_of_points:list, name_x="x", name_y="y", plot_title="title", filename_to_save="nopdf", marker_type="o", marker_size="5"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    
    # Plot data

    # [data_x, data_y, label, color]
    
    for l in list_of_data:
        data_x, data_y, label, colorr, line_style = l
        plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle=line_style, color=colorr, markersize=marker_size) # color='red')
    
    for p in list_of_points:
        # plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle=line_style, color=colorr, markersize=marker_size)

        x_val, y_val, labell, markerr, markersizee, colorr = p

        plt.plot(x_val, y_val, label=labell, marker=markerr, markersize=markersizee, color=colorr)
    
    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".svg"
        plt.savefig(fnts)

    plt.show()

# %%
data_1000 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/deposition/231103 SK100 deposition/SK100.csv', sep=';')

x_1000 = data_1000.Time[160:8058]
y_1000 = data_1000.Area[160:8058]

where = 400
p1_x = data_1000.Time[where]
p1_y = data_1000.Area[where]

plot_with_one_axis_with_ONE_points(x_1000,y_1000, "name_x", "name_y", p1_x, p1_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="1", main_color="#1f77b4") #, xmin=0, xmax=500000, ymin=0, ymax=1000):

print(f"(100:0) max: {p1_y}, min: {min(y_1000)}, delta Area = {p1_y - min(y_1000)}")

A_1000 = p1_y - min(y_1000)
# Out:
# (100:0) max: 172.782, min: 164.682, delta Area = 8.100000000000023

# %%
data_9010 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/deposition/250924 SK100 DTP10 90 10 mix deposition/deposition S_D 90 10 mix.csv', sep=';')

x_9010 = data_9010.Time[100:8926]
y_9010 = data_9010.Area[100:8926]

# print(f"(90:10) max: {max(y_9010)}, min: {min(y_9010)}, delta Area = {max(y_9010) - min(y_9010)}")

# simple_plot(x_9010,y_9010)

where = 400
p1_x = data_9010.Time[where]
p1_y = data_9010.Area[where]

plot_with_one_axis_with_ONE_points(x_9010,y_9010, "name_x", "name_y", p1_x, p1_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="1", main_color="#1f77b4") #, xmin=0, xmax=500000, ymin=0, ymax=1000):

print(f"(100:0) max: {p1_y}, min: {min(y_9010)}, delta Area = {p1_y - min(y_9010)}")

A_9010 = p1_y - min(y_9010)
# Out:
# (100:0) max: 270.401, min: 243.333, delta Area = 27.068000000000012

# %%
data_7030 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/deposition/230924 SK100 DTP10 70 30 mix deposition/70 30 S_D mix deposition.csv', sep=';')

x_7030 = data_7030.Time[120:]
y_7030 = data_7030.Area[120:]

# print(f"(70:30) max: {max(y_7030)}, min: {min(y_7030)}, delta Area = {max(y_7030) - min(y_7030)}")


# simple_plot(x_7030,y_7030)

where = 400
p1_x = data_7030.Time[where]
p1_y = data_7030.Area[where]

plot_with_one_axis_with_ONE_points(x_7030,y_7030, "name_x", "name_y", p1_x, p1_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="1", main_color="#1f77b4") #, xmin=0, xmax=500000, ymin=0, ymax=1000):

print(f"(100:0) max: {p1_y}, min: {min(y_7030)}, delta Area = {p1_y - min(y_7030)}")


A_7030 = p1_y - min(y_7030)
# Out:
# (100:0) max: 421.383, min: 371.293, delta Area = 50.089999999999975

# %%
data_5050 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/deposition/180924 SK100 DTP10 50 50 mix deposition/SK100 DTP10 50 50 depo.csv', sep=';')

x_5050 = data_5050.Time[100:]
y_5050 = data_5050.Area[100:]

# print(f"(50:50) max: {max(y_5050)}, min: {min(y_5050)}, delta Area = {max(y_5050) - min(y_5050)}")


# simple_plot(x_5050,y_5050)

where = 400
p1_x = data_5050.Time[where]
p1_y = data_5050.Area[where]

plot_with_one_axis_with_ONE_points(x_5050,y_5050, "name_x", "name_y", p1_x, p1_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="1", main_color="#1f77b4") #, xmin=0, xmax=500000, ymin=0, ymax=1000):

print(f"(100:0) max: {p1_y}, min: {min(y_5050)}, delta Area = {p1_y - min(y_5050)}")

A_5050 = p1_y - min(y_5050)
# Out:
# (100:0) max: 160.504, min: 144.089, delta Area = 16.414999999999992

# %%
data_3070 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/deposition/230924 SK100 DTP10 30 70 mix deposition/230924 SK100 DTP10 30 70 mix deposition.csv', sep=';')

x_3070 = data_3070.Time[150:]
y_3070 = data_3070.Area[150:]

# print(f"(30:70) max: {max(y_3070)}, min: {min(y_3070)}, delta Area = {max(y_3070) - min(y_3070)}")


# simple_plot(x_3070,y_3070)

where = 300
p1_x = data_3070.Time[where]
p1_y = data_3070.Area[where]

plot_with_one_axis_with_ONE_points(x_3070,y_3070, "name_x", "name_y", p1_x, p1_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="1", main_color="#1f77b4") #, xmin=0, xmax=500000, ymin=0, ymax=1000):

print(f"(100:0) max: {p1_y}, min: {min(y_3070)}, delta Area = {p1_y - min(y_3070)}")


A_3070 = p1_y - min(y_3070)
# Out:
# (100:0) max: 426.02, min: 367.052, delta Area = 58.96799999999996

# %%
data_1090 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/deposition/250924 SK100 DTP10 10 90 mix deposition/SK100 DTP10 10 90 deposition.csv', sep=';')

x_1090 = data_1090.Time[200:8340]
y_1090 = data_1090.Area[200:8340]

# print(f"(10:90) max: {max(y_1090)}, min: {min(y_1090)}, delta Area = {max(y_1090) - min(y_1090)}")


# simple_plot(x_1090,y_1090)

where = 800
p1_x = data_1090.Time[where]
p1_y = data_1090.Area[where]

plot_with_one_axis_with_ONE_points(x_1090,y_1090, "name_x", "name_y", p1_x, p1_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="1", main_color="#1f77b4") #, xmin=0, xmax=500000, ymin=0, ymax=1000):

print(f"(100:0) max: {p1_y}, min: {min(y_1090)}, delta Area = {p1_y - min(y_1090)}")


A_1090 = p1_y - min(y_1090)
# Out:
# (100:0) max: 184.544, min: 161.516, delta Area = 23.02800000000002

# %%
data_0100 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/deposition/240903 DTP10 depo/DTP10 deposition.csv', sep=';')

x_0100 = data_0100.Time[183:]
y_0100 = data_0100.Area[183:]

# print(f"(0:100) max: {max(y_0100)}, min: {min(y_0100)}, delta Area = {max(y_0100) - min(y_0100)}")


# simple_plot(x_0100,y_0100)

where = 800
p1_x = data_0100.Time[where]
p1_y = data_0100.Area[where]

print(min(y_0100))

plot_with_one_axis_with_ONE_points(x_0100,y_0100, "name_x", "name_y", p1_x, p1_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="1", main_color="#1f77b4") #, xmin=0, xmax=500000, ymin=0, ymax=1000):

print(f"(100:0) max: {p1_y}, min: {min(y_0100)}, delta Area = {p1_y - min(y_0100)}")





A_0100 = p1_y - min(y_0100)

min_index = y_0100.idxmin()

# Get the corresponding x-value for the minimum y-value
x_min = x_0100[min_index]
y_min = y_0100[min_index]

print(x_min, y_min)
# Out:
# 624.581
# (100:0) max: 719.286, min: 624.581, delta Area = 94.70499999999993
# 3201.43 624.581

# %%
# (100:0) max: 173.542, min: 164.682, delta Area = 8.860000000000014
# (90:10) max: 272.87, min: 243.333, delta Area = 29.537000000000006
# (70:30) max: 428.093, min: 371.293, delta Area = 56.80000000000001
# (50:50) max: 162.567, min: 144.089, delta Area = 18.47800000000001
# (30:70) max: 429.975, min: 367.052, delta Area = 62.923
# (10:90) max: 190.491, min: 161.516, delta Area = 28.975000000000023
# (0:100) max: 123.032, min: 117.888, delta Area = 5.143999999999991

# a_1000 = 8.860000000000014 # mm² = 1e-6m²
# a_9010 = 29.537000000000006
# a_7030 = 56.80000000000001
# a_5050 = 18.47800000000001
# a_3070 = 62.923
# a_1090 = 28.975000000000023
# a_0100 = 5.143999999999991


A_0100
A_1090
A_3070
A_5050
A_7030
A_9010
A_1000


Dtp10_ratio = [0,10,30,50,70,90,100]
delta_A = [A_1000, A_9010, A_7030, A_5050, A_3070, A_1090, A_0100]

area_substrate = 15*15

y = []


for dA in delta_A:
    TR = dA / area_substrate
    y.append(TR)
    print(f"transfer ratio = {TR}")

def lin_func(x,offset,slope):
    return slope*x + offset


x_fit = np.linspace(min(Dtp10_ratio), max(Dtp10_ratio), 100)

popt, pcov = curve_fit(lin_func, Dtp10_ratio, y)

y_fit = lin_func(x_fit, *popt)



lll = [
    [Dtp10_ratio, y, "Data", "dimgray", "-"],
    #[x_fit, y_fit, "bla", "dimgray", ""]
    ]
plot_with_one_axis(lll, name_x="Percentage of ratio of Dtp10", name_y="Transfer ratio", plot_title="Transfer ratios for increased Dtp10 concentration", filename_to_save="python_figures/Transfer ratios for increased Dtp10 concentration", marker_type="s", marker_size="5")
# Out:
# transfer ratio = 0.0360000000000001
# transfer ratio = 0.12030222222222228
# transfer ratio = 0.2226222222222221
# transfer ratio = 0.07295555555555552
# transfer ratio = 0.2620799999999998
# transfer ratio = 0.10234666666666675
# transfer ratio = 0.4209111111111108

# %%
a = [
    [x_1000, y_1000, "100:0 mix", "yellow", "-"],
    [x_9010, y_9010, "90:10 mix", "orange", "-"],
    [x_7030, y_7030, "70:30 mix", "red", "-"],
    [x_5050, y_5050, "50:50 mix", "purple", "-"],
    [x_3070, y_3070, "30:70 mix", "lightblue", "-"],
    [x_1090, y_1090, "10:90 mix", "blue", "-"],
    [x_0100, y_0100, "0:100 mix", "green", "-"]
]


p = [
    [200.4, 719.286,"", "s", "5", "green"],
    [3201.43, 624.581, "", "s", "5", "green"]
]


plot_with_one_axis_with_points(a,p, "Time [s]", r"Area [mm]$^2$", "Deposition of different mixtures of Sk100:Dpt10", "python_figures/deposition", "", "1")
