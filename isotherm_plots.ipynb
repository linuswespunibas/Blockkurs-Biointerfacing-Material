# %%
# import
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit
import math

# %%
# Enable LaTeX rendering
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Computer Modern Roman'
plt.rcParams['text.latex.preamble'] = r"\usepackage{amsmath}"

# %%
# funktionen
def simple_plot(x,y):
    # Create some data

    # Plot
    plt.plot(x, y, label=r'$\sin(x)$')
    plt.xlabel(r'$x$')
    plt.ylabel(r'$\sin(x)$')
    plt.title(r'Plot of $\sin(x)$ using LaTeX')
    plt.legend()
    plt.show()

# plot with one axis
# col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5"
def plot_with_one_axis(data_x, data_y, name_x, name_y, plot_title="title", filename_to_save="nopdf", label="nolabel", colorr="#1f77b4", marker_type="o", marker_size="5"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    
    # Plot data
    plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle='-', color=colorr, markersize=marker_size) # color='red') 
    
    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".svg"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_with_points(data_x, data_y, name_x, name_y, p1_x, p1_y, p2_x, p2_y, plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="5", main_color="#1f77b4"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    # col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5"

    # Plot data
    plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle='', markersize=marker_size, color=main_color) 
    # plt.plot(0.096,58.496, label=f"$x = 0.096$ mm", marker='o', markersize=6)
    # plt.plot(0.166,16.31, label=f"$x = 0.166$ mm", marker='o', markersize=6)
    plt.plot(p1_x,p1_y, label=f"$x = 0.096$ mm", marker='o', markersize=6, color = "orange")
    plt.plot(p2_x,p2_y, label=f"$x = 0.166$ mm", marker='o', markersize=6, color = "green")
    

    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_twoY(data_x_1, data_y_1, data_x_2, data_y_2,  name_x, name_y, plot_title="title", filename_to_save="nopdf", line_style="", label1="nolabel", label2="nolabel", col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5", plot_point="nopoint"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    


    
    # Plot data
    plt.plot(data_x_1, data_y_1, label=label1, marker=marker_type, linestyle=line_style, markersize=marker_size, color=col1) # color='red') 
    plt.plot(data_x_2, data_y_2, label=label2, marker=marker_type, color=col2, linestyle=line_style, markersize=marker_size) #, marker='o', linestyle='') # color='red') 
    
    if plot_point != "nopoint":
        # xx, yy = plot_point
        xx, yy, labell, markerr, markersizee, colorr = plot_point

        plt.plot(xx, yy, label=labell, marker=markerr, markersize=markersizee, color=colorr)

        #plt.plot(xx, yy, label="HALLO", markersize=10)

    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_and_two_fits(data_x, data_y, x_fit_1, y_fit_1, x_fit_2, y_fit_2, name_x, name_y, main_color="#1f77b4", colorfit1="orange", colorfit2="green", plot_title="title", filename_to_save="nopdf", label="nolabel", marker_type="o", marker_size="5"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    
    # Plot data
    plt.plot(data_x, data_y, label=label, marker=marker_type, linestyle='', markersize = marker_size, color=main_color) 
    plt.plot(x_fit_1, y_fit_1, color=colorfit1)
    plt.plot(x_fit_2, y_fit_2, color=colorfit2)
    
    
    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

# plot with two axes
def plot_with_two_axes(data_x,data_y_one, data_y_two, name_x, name_y1, name_y2, plot_title="title", filename_to_save="LOL.pdf", xmin=0, xmax=500000, ymin1=0, ymax1=1000, ymin2=-2, ymax2=1):
    fig, ax1 = plt.subplots() 
    
    ax1.set_xlabel(name_x) 
    ax1.set_ylabel(name_y1, color = 'red') 
    plot_1 = ax1.plot(data_x, data_y_one, color = 'red', label='impedance') 
    ax1.tick_params(axis ='y') #, labelcolor = 'red') 
    # ax1.ylim(0,.9)
    # ax1.xlim(0,.9)
    ax1.set_xlim([xmin, xmax])
    ax1.set_ylim([ymin1, ymax1])

    ax2 = ax1.twinx() 
    ax2.set_ylabel(name_y2, color = 'blue') 
    plot_2 = ax2.plot(data_x, data_y_two, color = 'blue', label = 'phase') 
    ax2.tick_params(axis ='y') #, labelcolor = 'blue') 

    ax1.set_xlim([xmin, xmax])
    ax2.set_ylim([ymin2, ymax2])
    
    fig.tight_layout()

    lns = plot_1 + plot_2
    labels = [l.get_label() for l in lns]
    
    plt.title(plot_title)
    plt.legend(lns, labels, loc=0)
    
    fnts =  filename_to_save + ".pdf"
    plt.savefig(fnts)
    plt.show()


def plot_with_one_axis_twoY_and_error_bars(data_x_1, data_y_1, data_y_1_error, data_x_2, data_y_2,  name_x, name_y, plot_title="title", filename_to_save="noname.pdf", line_style="", label1="nolabel", label2="nolabel", col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5", capsize_errorbars=5): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    plt.figure()  # No need for subplots when using a single axis
    
    # Plot data
    plt.errorbar(data_x_1, data_y_1, yerr=data_y_1_error, fmt=marker_type, label=label1, capsize=capsize_errorbars, color=col1)
    # plt.plot(data_x_1, data_y_1, label=label1, marker=marker_type, linestyle=line_style, markersize=marker_size, color=col1) # color='red') 
    plt.plot(data_x_2, data_y_2, label=label2, color=col2, linestyle="-") #, marker='o', linestyle='') # color='red') 



    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if filename_to_save != "nopdf":
        fnts = filename_to_save + ".pdf"
        plt.savefig(fnts)

    plt.show()

def plot_with_one_axis_twoY_with_point_from_list(lll, fname): # data_x_1, data_y_1, data_x_2, data_y_2,  name_x, name_y, plot_title="title", filename_to_save="nopdf", line_style="", label1="nolabel", label2="nolabel", col1="#1f77b4", col2="#ff7f0e", marker_type="o", marker_size="5", plot_point="nopoint"): #, xmin=0, xmax=500000, ymin=0, ymax=1000):
    
    l = lll
    
    plt.figure()  # No need for subplots when using a single axis
    
    for l in lll:
        #data_x_1, data_y_1, data_x_2, data_y_2, name_x, name_y, plot_title, filename_to_save, 
        data_x_1, data_y_1, data_x_2, data_y_2, name_x, name_y, plot_title, filename_to_save, line_style, label1, label2, col1, col2, marker_type, marker_size, plot_point = l

        # Plot data
        plt.plot(data_x_1, data_y_1, label=label1, marker=marker_type, linestyle=line_style, markersize=marker_size, color=col1) # color='red') 
        plt.plot(data_x_2, data_y_2, label=label2, marker=marker_type, color=col2, linestyle=line_style, markersize=marker_size) #, marker='o', linestyle='') # color='red') 
        
        if plot_point != "nopoint":
            # xx, yy = plot_point
            xx, yy, labell, markerr, markersizee, colorr = plot_point

            plt.plot(xx, yy, label=labell, marker=markerr, markersize=markersizee, color=colorr)

            #plt.plot(xx, yy, label="HALLO", markersize=10)

    # Label the axes
    plt.xlabel(name_x) 
    plt.ylabel(name_y) #, color='red')
    
    # Set axis limits
    # plt.xlim([xmin, xmax])
    # plt.ylim([ymin, ymax])
    
    # Set title and legend
    plt.title(plot_title)
    plt.legend(loc='best')
    
    # Save and show the plot
    if fname != "nopdf":
        fnts = fname + ".svg"
        plt.savefig(fnts)

    plt.show()

# %%
# 0:100

data_0100_1 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/230905 DTP10 triblock iso/triblock  DTP10 - iso1.csv', sep=';')
data_0100_2 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/230905 DTP10 triblock iso/triblock  DTP10 - iso2.csv', sep=';')

x1_0100 = data_0100_1.Area[4450:-90] - 1
y1_0100 = data_0100_1.Pressure[4450:-90] - 1

print(x1_0100)

x2_0100 = data_0100_2.Area[800:]
y2_0100 = data_0100_2.Pressure[800:]


col_0100 = "black"
pp = [847.0, 35.5967, f"deposition parameter 0:100: {round(35.5967,3)} mN/m", "o", 8, col_0100]
plot_with_one_axis_twoY(x1_0100, y1_0100, x2_0100, y2_0100,  f"Area [mm$^2$]", "Tension [mN/m]", plot_title="Compression Isotherm 0:100 triblock mixture", filename_to_save="nopdf", line_style="-", label1="", label2="", col1=col_0100, col2=col_0100, marker_type="s", marker_size="1", plot_point=pp) #, xmin=0, xmax=500000, ymin=0, ymax=1000):
# Out:
# 4450    1067.560
# 4451    1066.020
# 4452    1064.290
# 4453    1062.750
# 4454    1061.010
#           ...
# 4506     974.377
# 4507     972.837
# 4508     971.104
# 4509     969.564
# 4510     968.023
# Name: Area, Length: 61, dtype: float64

# %%
# 10:90

data_10_90_1 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/240924 SK100 DTP10 10 90 mix isotherm/10 90 isotherm1.csv', sep=';')
data_10_90_2 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/240924 SK100 DTP10 10 90 mix isotherm/10 90 isotherm2.csv', sep=';')

x1_1090 = data_10_90_1.Area
y1_1090 = data_10_90_1.Pressure

x2_1090 = data_10_90_2.Area#[380:400]
y2_1090 = data_10_90_2.Pressure#[380:400]

col_1090 = "blue"
pp = [156.106, 45.3164, f"deposition parameter 10:90: {round(45.3164,3)} mN/m", "o", 8, col_1090]
plot_with_one_axis_twoY(x1_1090, y1_1090, x2_1090, y2_1090,  f"Area [mm$^2$]", "Tension [mN/m]", plot_title="Compression Isotherm 10:90 triblock mixture", filename_to_save="nopdf", line_style="-", label1="", label2="", col1=col_1090, col2=col_1090, marker_type="s", marker_size="1", plot_point=pp) #, xmin=0, xmax=500000, ymin=0, ymax=1000):

# [x1_1090, y1_1090, x2_1090, y2_1090,  f"Area [mm$^2$]", "Tension [mN/m]", "Compression Isotherm 50:50 triblock mixture", "nopdf", "-", "", "", col_1090, col_1090, "s", "1", pp]

# %%
# 30:70

data_30_70_1 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/200924 SK100 DTP10 30_70 mix isotherm/SK100 DTP10 30_70 mix iso1.csv', sep=';')
data_30_70_2 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/200924 SK100 DTP10 30_70 mix isotherm/SK100 DTP10 30_70 mix iso2.csv', sep=';')

x1_3070 = data_30_70_1.Area#[300:]
y1_3070 = data_30_70_1.Pressure#[300:]



x2_3070 = data_30_70_2.Area#[350:380]
y2_3070 = data_30_70_2.Pressure#[350:380]
# print(len(x2_3070))


col_3070 = "green"
pp = [200.321, 50.375, f"deposition parameter 30:70: {round(50.375,3)} mN/m", "o", 8, col_3070]
plot_with_one_axis_twoY(x1_3070, y1_3070, x2_3070, y2_3070,  f"Area [mm$^2$]", "Tension [mN/m]", plot_title="Compression Isotherm 50:50 triblock mixture", filename_to_save="nopdf", line_style="-", label1="", label2="", col1=col_3070, col2=col_3070, marker_type="s", marker_size="1", plot_point=pp) #, xmin=0, xmax=500000, ymin=0, ymax=1000):

# %%
# 50:50

data_50_50_1 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/190924 SK100 DTP10 50 50 mix isotherm/50 50 mix iso1.csv', sep=';')
data_50_50_2 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/190924 SK100 DTP10 50 50 mix isotherm/50 50 mix iso2.csv', sep=';')


x1_5050 = data_50_50_1.Area[390:-20]#[300:]
y1_5050 = data_50_50_1.Pressure[390:-20] + 0.5#[300:] +

x2_5050 = data_50_50_2.Area[60:]
y2_5050 = data_50_50_2.Pressure[60:]


col_5050 = "red"
pp = [172.982, 51.4519, f"deposition parameter 50:50: {round(51.4519,3)} mN/m", "o", 8, col_5050]

plot_with_one_axis_twoY(x1_5050, y1_5050, x2_5050, y2_5050,  f"Area [mm$^2$]", "Tension [mN/m]", plot_title="Compression Isotherm 50:50 triblock mixture", filename_to_save="nopdf", line_style="-", label1="", label2="", col1=col_5050, col2=col_5050, marker_type="s", marker_size="1",plot_point=pp) #, xmin=0, xmax=500000, ymin=0, ymax=1000):

# %%
# 70:30

data_7030_1 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/190924 SK100 DTP10 70_30 mix isotherm/70 30 S_D mix iso1.csv', sep=';')
data_7030_2 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/190924 SK100 DTP10 70_30 mix isotherm/70 30 S_D mix iso2.csv', sep=';')


x1_7030 = data_7030_1.Area#[300:]
y1_7030 = data_7030_1.Pressure#[300:]

x2_7030 = data_7030_2.Area#[340:380]
y2_7030 = data_7030_2.Pressure#[340:380]





col_7030 = "orange"
pp = [160.981, 50.6131, f"deposition parameter 70:30: {round(50.6131,3)} mN/m", "o", 8, col_7030]


plot_with_one_axis_twoY(x1_7030, y1_7030, x2_7030, y2_7030,  f"Area [mm$^2$]", "Tension [mN/m]", plot_title="Compression Isotherm 50:50 triblock mixture", filename_to_save="nopdf", line_style="-", label1="", label2="", col1=col_7030, col2=col_7030, marker_type="s", marker_size="1", plot_point=pp) #, xmin=0, xmax=500000, ymin=0, ymax=1000):

# %%
# 90:10

data_9010_1 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/250924 SK100 DTP10 90 10 mix isotherm/SK100 DTP10 90 10 mix iso1.csv', sep=';')
data_9010_2 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/250924 SK100 DTP10 90 10 mix isotherm/SK100 DTP10 90 10 mix iso2.csv', sep=';')


x1_9010 = data_9010_1.Area#[300:]
y1_9010 = data_9010_1.Pressure#[300:]

x2_9010 = data_9010_2.Area#[200:320]
y2_9010 = data_9010_2.Pressure#[200:320]


col_9010 = "lightblue"
pp = [170.517, 52.4144, f"deposition parameter 90:10: {round(52.41446131,3)} mN/m", "o", 8, col_9010]


plot_with_one_axis_twoY(x1_9010, y1_9010, x2_9010, y2_9010,  f"Area [mm$^2$]", "Tension [mN/m]", plot_title="Compression Isotherm 50:50 triblock mixture", filename_to_save="nopdf", line_style="-", label1="", label2="", col1=col_9010, col2=col_9010, marker_type="s", marker_size="1", plot_point=pp) #, xmin=0, xmax=500000, ymin=0, ymax=1000):

# %%
# 100:0

data_1000_1 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/240424 SK100 triblock iso/iso1.csv', sep=';')
data_1000_2 = pd.read_csv('data/Linus & Alicia miniLB and QCM/Linus & Alicia as csv/isotherm/240424 SK100 triblock iso/iso2.csv', sep=';')


x1_1000 = data_1000_1.Area[140:] + 35    #[300:]
y1_1000 = data_1000_1.Pressure[140:]   #[300:]

x2_1000 = data_1000_2.Area#[150:200]
y2_1000 = data_1000_2.Pressure#[150:200]


col_1000 = "purple"
pp = [131.072, 52.4945, f"deposition parameter 100:0: {round(52.4945,3)} mN/m", "o", 8, col_1000]


plot_with_one_axis_twoY(x1_1000, y1_1000, x2_1000, y2_1000,  f"Area [mm$^2$]", "Tension [mN/m]", plot_title="Compression Isotherm 50:50 triblock mixture", filename_to_save="nopdf", line_style="-", label1="", label2="", col1=col_1000, col2=col_1000, marker_type="s", marker_size="1", plot_point=pp) #, xmin=0, xmax=500000, ymin=0, ymax=1000):

# %%
# all ratios

col_1090 = "blue"
col_0100 = "black"
col_3070 = "green"
col_5050 = "red"
col_7030 = "orange"
col_9010 = "lightblue"
col_1000 = "purple"


a =  [
    [x1_0100, y1_0100, x2_0100, y2_0100,  f"Area [mm$^2$]", "Tension [mN/m]", "Compression Isotherm 50:50 triblock mixture", "nopdf", "-", "", "", col_0100, col_0100, "s", "0.1", [847.0, 35.5967, f"deposition parameter 0:100: {round(35.5967,3)} mN/m", "o", 8, col_0100]],
    #[x1_1090, y1_1090, x2_1090, y2_1090,  f"Area [mm$^2$]", "Tension [mN/m]", "Compression Isotherm 50:50 triblock mixture", "nopdf", "-", "", "", col_1090, col_1090, "s", "0.1", [156.106, 45.3164, f"deposition parameter 10:90: {round(45.3164,3)} mN/m", "o", 8, col_1090]],
    #[x1_3070, y1_3070, x2_3070, y2_3070,  f"Area [mm$^2$]", "Tension [mN/m]", "Compression Isotherm 50:50 triblock mixture", "nopdf", "-", "", "", col_3070, col_3070, "s", "0.1", [200.321, 50.375, f"deposition parameter 30:70: {round(50.375,3)} mN/m", "o", 8, col_3070]],
    [x1_5050, y1_5050, x2_5050, y2_5050,  f"Area [mm$^2$]", "Tension [mN/m]", "Compression Isotherm 50:50 triblock mixture", "nopdf", "-", "", "", col_5050, col_5050, "s", "0.1",[172.982, 51.4519, f"deposition parameter 50:50: {round(51.4519,3)} mN/m", "o", 8, col_5050]],
    #[x1_7030, y1_7030, x2_7030, y2_7030,  f"Area [mm$^2$]", "Tension [mN/m]", "Compression Isotherm 50:50 triblock mixture", "nopdf", "-", "", "", col_7030, col_7030, "s", "0.1", [160.981, 50.6131, f"deposition parameter 70:30: {round(50.6131,3)} mN/m", "o", 8, col_7030]],
    #[x1_9010, y1_9010, x2_9010, y2_9010,  f"Area [mm$^2$]", "Tension [mN/m]", "Compression Isotherm 50:50 triblock mixture", "nopdf", "-", "", "", col_9010, col_9010, "s", "0.1", [170.517, 52.4144, f"deposition parameter 90:10: {round(52.41446131,3)} mN/m", "o", 8, col_9010]],
    [x1_1000, y1_1000, x2_1000, y2_1000,  f"Area [mm$^2$]", "Tension [mN/m]", "Compression isotherms of different Sk100:Dpt10 mixtures", "compression_isotherms", "-", "", "", col_1000, col_1000, "s", "0.1", [131.072, 52.4945, f"deposition parameter 100:0: {round(52.4945,3)} mN/m", "o", 8, col_1000]]
 
]


plot_with_one_axis_twoY_with_point_from_list(a, "python_figures/deposition_parameters")

# %%
Sk100_percentage = [0, 10,30,50,70,90,100]
ratio_deposition_parameter = [35.597 , 45.3164, 50.375, 51.4519, 50.6131, 52.41446131, 52.4945]

plot_with_one_axis(Sk100_percentage, ratio_deposition_parameter, r"Sk100 ratio [$\%$]", "Tension [mN/m]", plot_title="Deposition parameters for different Sk100 ratios", filename_to_save="python_figures/Deposition parameters for different Sk100 ratios", label="Tension", colorr="dimgray", marker_type="s", marker_size="5")
